# %%
#!rm -rf Intern_VSF/
# !git clone https://github.com/duonghieu2/voice-chatbot-agent.git
# %cd voice-chatbot-agent
# Out:
# Cloning into 'voice-chatbot-agent'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 93 (delta 12), reused 91 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (93/93), 869.42 KiB | 3.40 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/voice-chatbot-agent

# %%
# !python colab_run.py --install
# Out:
# Google Colab Helper Script for Voice Chatbot Agent
# Usage:
#   python colab_run.py --install     # Install all dependencies
#   python colab_run.py --evaluate    # Run Whisper ASR evaluation (defaults to 'base' model)
#   python colab_run.py --eval-large  # Run evaluation with 'large-v3' model (requires GPU)
#   python colab_run.py --test        # Run pytest unit tests
#   python colab_run.py --server      # Start FastAPI backend server
# ------------------------------------------------------------
# ...
# CHECKING GPU AVAILABILITY
# ...
# CUDA Available: True
# Device Name   : Tesla T4
# Device Count  : 1
# ...
#
# ...
# INSTALLING DEPENDENCIES VIA UV
# ...
# [+] Installing 'uv' package manager...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 84.7 MB/s eta 0:00:00
# ...
# [+] Syncing project dependencies with uv...
# Using Python 3.12.13 environment at: /usr
# Resolved 103 packages in 940ms
# Prepared 26 packages in 50.63s
# Uninstalled 6 packages in 611ms
# Installed 26 packages in 291ms
# ...

# %%
# !python colab_run.py --evaluate
# Out:
# Google Colab Helper Script for Voice Chatbot Agent
# Usage:
#   python colab_run.py --install     # Install all dependencies
#   python colab_run.py --evaluate    # Run Whisper ASR evaluation (defaults to 'base' model)
#   python colab_run.py --eval-large  # Run evaluation with 'large-v3' model (requires GPU)
#   python colab_run.py --test        # Run pytest unit tests
#   python colab_run.py --server      # Start FastAPI backend server
# ------------------------------------------------------------
# ...
# RUNNING ASR EVALUATION (Model: base)
# ...
# STARTING ASR BASELINE EVALUATION (Model: base)
# ...
# [+] Loaded 20 ground truth prompts from prompts.json.
# [+] Pre-warming Whisper model...
# Loading Whisper model 'base' on cuda...
#
#   0%|                                               | 0.00/139M [00:00<?, ?iB/s]
#   3%|█▏                                    | 4.20M/139M [00:00<00:03, 44.0MiB/s]
#  23%|████████▊                              | 31.3M/139M [00:00<00:00, 185MiB/s]
# ...

# %%
# !python colab_run.py --eval-large
# Out:
# Google Colab Helper Script for Voice Chatbot Agent
# Usage:
#   python colab_run.py --install     # Install all dependencies
#   python colab_run.py --evaluate    # Run Whisper ASR evaluation (defaults to 'base' model)
#   python colab_run.py --eval-large  # Run evaluation with 'large-v3' model (requires GPU)
#   python colab_run.py --test        # Run pytest unit tests
#   python colab_run.py --server      # Start FastAPI backend server
# ------------------------------------------------------------
# ...
# RUNNING ASR EVALUATION (Model: large-v3)
# ...
# STARTING ASR BASELINE EVALUATION (Model: large-v3)
# ...
# [+] Loaded 20 ground truth prompts from prompts.json.
# [+] Pre-warming Whisper model...
# Loading Whisper model 'large-v3' on cuda...
#
#   0%|                                              | 0.00/2.88G [00:00<?, ?iB/s]
#   0%|                                     | 2.77M/2.88G [00:00<01:46, 29.0MiB/s]
#   1%|▎                                     | 19.6M/2.88G [00:00<00:27, 114MiB/s]
# ...

# %%
# Chạy server ở chế độ nền, ghi log vào file server.log
# !python colab_run.py --server > server.log 2>&1 &

# Khởi chạy server uvicorn trực tiếp với cấu hình Whisper large-v3 trong nền
# !USE_MOCK_ASR=False WHISPER_MODEL_NAME=large-v3 python -m uvicorn app.main:app --host 0.0.0.0 --port 8000 > server.log 2>&1 &

# %%
# Cài đặt localtunnel qua npm
# !npm install -g localtunnel

# Expose cổng 8000 ra ngoài
# !lt --port 8000
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 22 packages in 3s
# ⠸
# ⠸3 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸your url is: https://sour-pillows-hammer.loca.lt
