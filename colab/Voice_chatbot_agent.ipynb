# %%
# !rm -rf voice-chatbot-agent/ Intern_VSF/
# !git clone https://github.com/duonghieu2/voice-chatbot-agent.git
# %cd voice-chatbot-agent
# Out:
# Cloning into 'voice-chatbot-agent'...
# remote: Enumerating objects: 226, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (169/169), done.
# remote: Total 226 (delta 91), reused 189 (delta 54), pack-reused 0 (from 0)
# Receiving objects: 100% (226/226), 1.41 MiB | 31.97 MiB/s, done.
# Resolving deltas: 100% (91/91), done.
# /content/voice-chatbot-agent/voice-chatbot-agent

# %%
import os
from google.colab import userdata

# Khởi tạo danh sách các biến cần nạp
keys = ["GEMINI_API_KEY", "USE_MOCK_ASR", "WHISPER_MODEL_NAME", "LLM_MODEL_NAME"]

print("=== NẠP CẤU HÌNH TỪ COLAB SECRETS ===")
for key in keys:
    try:
        val = userdata.get(key)
        if val is not None:
            os.environ[key] = str(val)
            print(f"[+] Đã nạp thành công: {key}")
    except Exception as e:
        print(f"[-] Bỏ qua hoặc lỗi khi nạp {key}: {str(e)}")
# Out:
# === NẠP CẤU HÌNH TỪ COLAB SECRETS ===
# [+] Đã nạp thành công: GEMINI_API_KEY
# [+] Đã nạp thành công: USE_MOCK_ASR
# [+] Đã nạp thành công: WHISPER_MODEL_NAME
# [+] Đã nạp thành công: LLM_MODEL_NAME

# %%
# !python colab_run.py --install
# Out:
# Google Colab Helper Script for Voice Chatbot Agent
# Usage:
#   python colab_run.py --install     # Install all dependencies
#   python colab_run.py --evaluate    # Run Whisper ASR evaluation (defaults to 'small' model)
#   python colab_run.py --eval-base   # Run evaluation with 'base' model
#   python colab_run.py --eval-large  # Run evaluation with 'large-v3' model (requires GPU)
#   python colab_run.py --test        # Run pytest unit tests
#   python colab_run.py --server      # Start FastAPI backend server
# ------------------------------------------------------------
# ...
# CHECKING GPU AVAILABILITY
# ...
# CUDA Available: True
# Device Name   : Tesla T4
# Device Count  : 1
# ...
#
# ...
# INSTALLING DEPENDENCIES VIA UV
# ...
# [+] 'uv' is already installed.
# [+] Syncing project dependencies with uv...
# Using Python 3.12.13 environment at: /usr
# Resolved 103 packages in 604ms
# Checked 103 packages in 1ms
# Using Python 3.12.13 environment at: /usr
# Checked 7 packages in 104ms
# ...

# %%
# Đánh giá hệ thống ASR với model mặc định (Whisper 'small')
# !python colab_run.py --evaluate
# Out:
# Google Colab Helper Script for Voice Chatbot Agent
# Usage:
#   python colab_run.py --install     # Install all dependencies
#   python colab_run.py --evaluate    # Run Whisper ASR evaluation (defaults to 'small' model)
#   python colab_run.py --eval-base   # Run evaluation with 'base' model
#   python colab_run.py --eval-large  # Run evaluation with 'large-v3' model (requires GPU)
#   python colab_run.py --test        # Run pytest unit tests
#   python colab_run.py --server      # Start FastAPI backend server
# ------------------------------------------------------------
# ...
# RUNNING ASR EVALUATION (Model: small)
# ...
# /content/voice-chatbot-agent/voice-chatbot-agent/app/services/agent_service.py:7: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# ...

# %%
# Đánh giá hệ thống ASR với model Whisper 'base' để so sánh hiệu năng
# !python colab_run.py --eval-base
# Out:
# Google Colab Helper Script for Voice Chatbot Agent
# Usage:
#   python colab_run.py --install     # Install all dependencies
#   python colab_run.py --evaluate    # Run Whisper ASR evaluation (defaults to 'small' model)
#   python colab_run.py --eval-base   # Run evaluation with 'base' model
#   python colab_run.py --eval-large  # Run evaluation with 'large-v3' model (requires GPU)
#   python colab_run.py --test        # Run pytest unit tests
#   python colab_run.py --server      # Start FastAPI backend server
# ------------------------------------------------------------
# ...
# RUNNING ASR EVALUATION (Model: base)
# ...
# /content/voice-chatbot-agent/voice-chatbot-agent/app/services/agent_service.py:7: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# ...

# %%
# Đánh giá hệ thống ASR với model Whisper 'large-v3' (Yêu cầu môi trường GPU)
# !python colab_run.py --eval-large
# Out:
# Google Colab Helper Script for Voice Chatbot Agent
# Usage:
#   python colab_run.py --install     # Install all dependencies
#   python colab_run.py --evaluate    # Run Whisper ASR evaluation (defaults to 'small' model)
#   python colab_run.py --eval-base   # Run evaluation with 'base' model
#   python colab_run.py --eval-large  # Run evaluation with 'large-v3' model (requires GPU)
#   python colab_run.py --test        # Run pytest unit tests
#   python colab_run.py --server      # Start FastAPI backend server
# ------------------------------------------------------------
# ...
# RUNNING ASR EVALUATION (Model: large-v3)
# ...
# /content/voice-chatbot-agent/voice-chatbot-agent/app/services/agent_service.py:7: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# ...

# %%
# Khởi chạy server FastAPI trong tiến trình nền (Sử dụng model mặc định 'small')
# !python colab_run.py --server > server.log 2>&1 &

# %%
# 1. Tải và cài đặt Cloudflare Tunnel client
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# 2. Expose cổng 8000 của FastAPI ra Internet
# !cloudflared tunnel --url http://localhost:8000
# Out:
# --2026-06-24 02:51:35--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.6.1/cloudflared-linux-amd64.deb [following]
# --2026-06-24 02:51:36--  https://github.com/cloudflare/cloudflared/releases/download/2026.6.1/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...
